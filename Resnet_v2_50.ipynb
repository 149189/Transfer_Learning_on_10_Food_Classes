# %%
pip install "tensorflow>=2.0.0"
# Out:
# Requirement already satisfied: tensorflow>=2.0.0 in c:\users\kaust\anaconda3\lib\site-packages (2.17.0)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow>=2.0.0) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0.0) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0.0) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0.0) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0.0) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0.0) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0.0) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0.0) (3.3.0)
# Requirement already satisfied: packaging in c:\users\kaust\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0.0) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0.0) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0.0) (2.32.2)
# Requirement already satisfied: setuptools in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0.0) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\kaust\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0.0) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0.0) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0.0) (1.65.4)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0.0) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0.0) (3.4.1)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=2.0.0) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\kaust\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow>=2.0.0) (0.43.0)
# Requirement already satisfied: rich in c:\users\kaust\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow>=2.0.0) (13.3.5)
# Requirement already satisfied: namex in c:\users\kaust\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow>=2.0.0) (0.0.8)
# Requirement already satisfied: optree in c:\users\kaust\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow>=2.0.0) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kaust\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow>=2.0.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kaust\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow>=2.0.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kaust\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow>=2.0.0) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kaust\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow>=2.0.0) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\kaust\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow>=2.0.0) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\kaust\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow>=2.0.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\kaust\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow>=2.0.0) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\kaust\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow>=2.0.0) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\kaust\anaconda3\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow>=2.0.0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\kaust\appdata\roaming\python\python312\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow>=2.0.0) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kaust\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow>=2.0.0) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade tensorflow-hub
# Out:
# Requirement already satisfied: tensorflow-hub in c:\users\kaust\anaconda3\lib\site-packages (0.16.1)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-hub) (1.26.4)
# Requirement already satisfied: protobuf>=3.19.6 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-hub) (3.20.3)
# Requirement already satisfied: tf-keras>=2.14.1 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-hub) (2.17.0)
# Requirement already satisfied: tensorflow<2.18,>=2.17 in c:\users\kaust\anaconda3\lib\site-packages (from tf-keras>=2.14.1->tensorflow-hub) (2.17.0)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (3.3.0)
# Requirement already satisfied: packaging in c:\users\kaust\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (24.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (2.32.2)
# Requirement already satisfied: setuptools in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\kaust\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (1.65.4)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in c:\users\kaust\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (3.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\kaust\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (0.43.0)
# Requirement already satisfied: rich in c:\users\kaust\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (13.3.5)
# Requirement already satisfied: namex in c:\users\kaust\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (0.0.8)
# Requirement already satisfied: optree in c:\users\kaust\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kaust\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kaust\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kaust\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kaust\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\kaust\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\kaust\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\kaust\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\kaust\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\kaust\anaconda3\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\kaust\appdata\roaming\python\python312\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kaust\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras>=2.14.1->tensorflow-hub) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import zipfile
import os
import datetime
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow_hub as hub
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import urllib.request
from tensorflow.keras.models import load_model

# %%
for dirpath, dirnames, filenames in os.walk("10_food_classes_10_percent"):
  print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 2 directories and 0 images in '10_food_classes_10_percent'.
# There are 10 directories and 0 images in '10_food_classes_10_percent\test'.
# There are 0 directories and 250 images in '10_food_classes_10_percent\test\chicken_curry'.
# There are 0 directories and 250 images in '10_food_classes_10_percent\test\chicken_wings'.
# There are 0 directories and 250 images in '10_food_classes_10_percent\test\fried_rice'.
# There are 0 directories and 250 images in '10_food_classes_10_percent\test\grilled_salmon'.
# There are 0 directories and 250 images in '10_food_classes_10_percent\test\hamburger'.
# There are 0 directories and 250 images in '10_food_classes_10_percent\test\ice_cream'.
# There are 0 directories and 250 images in '10_food_classes_10_percent\test\pizza'.
# There are 0 directories and 250 images in '10_food_classes_10_percent\test\ramen'.
# There are 0 directories and 250 images in '10_food_classes_10_percent\test\steak'.
# There are 0 directories and 250 images in '10_food_classes_10_percent\test\sushi'.
# There are 10 directories and 0 images in '10_food_classes_10_percent\train'.
# There are 0 directories and 75 images in '10_food_classes_10_percent\train\chicken_curry'.
# There are 0 directories and 75 images in '10_food_classes_10_percent\train\chicken_wings'.
# There are 0 directories and 75 images in '10_food_classes_10_percent\train\fried_rice'.
# There are 0 directories and 75 images in '10_food_classes_10_percent\train\grilled_salmon'.
# There are 0 directories and 75 images in '10_food_classes_10_percent\train\hamburger'.
# There are 0 directories and 75 images in '10_food_classes_10_percent\train\ice_cream'.
# There are 0 directories and 75 images in '10_food_classes_10_percent\train\pizza'.
# There are 0 directories and 75 images in '10_food_classes_10_percent\train\ramen'.
# There are 0 directories and 75 images in '10_food_classes_10_percent\train\steak'.
# There are 0 directories and 75 images in '10_food_classes_10_percent\train\sushi'.

# %%
IMAGE_SHAPE = (224, 224)
BATCH_SIZE = 32

train_dir = "10_food_classes_10_percent/train/"
test_dir = "10_food_classes_10_percent/test/"

train_datagen = ImageDataGenerator(rescale=1/255.)
test_datagen = ImageDataGenerator(rescale=1/255.)

print("Training images:")
train_data_10_percent = train_datagen.flow_from_directory(train_dir,
                                               target_size=IMAGE_SHAPE,
                                               batch_size=BATCH_SIZE,
                                               class_mode="categorical")

print("Testing images:")
test_data = test_datagen.flow_from_directory(test_dir,
                                             target_size=IMAGE_SHAPE,
                                             batch_size=BATCH_SIZE,
                                             class_mode="categorical")
# Out:
# Training images:
# Found 750 images belonging to 10 classes.
# Testing images:
# Found 2500 images belonging to 10 classes.

# %%
def create_tensorboard_callback(dir_name, experiment_name):
    log_dir = dir_name + "/" + experiment_name + "/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir)
    print(f"Saving TensorBoard log files to: {log_dir}")
    return tensorboard_callback

# %%
def download_model(model_url, model_name, save_dir="models"):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, model_name + ".h5")
    
    if not os.path.exists(model_path):
        print(f"Downloading {model_name}...")
        urllib.request.urlretrieve(model_url, model_path)
        print(f"Saved {model_name} to {model_path}")
    else:
        print(f"{model_name} already exists at {model_path}")
    
    return model_path

# %%
resnet_url = "https://kaggle.com/models/google/resnet-v2/TensorFlow2/50-feature-vector/1"

efficientnet_url = "https://www.kaggle.com/models/tensorflow/efficientnet/TensorFlow2/b0-feature-vector/1"

# %%
def create_model(model_url, num_classes=10):
  feature_extractor_layer = hub.KerasLayer(model_url,
                                           trainable=False, 
                                           name='feature_extraction_layer',
                                           input_shape=IMAGE_SHAPE+(3,)) 

 
  model = tf.keras.Sequential([
    feature_extractor_layer, 
    layers.Dense(num_classes, activation='softmax', name='output_layer')
  ])

  return model

# %%
import tensorflow as tf
import tensorflow_hub as hub

num_classes = 10  

class KerasLayerWrapper(tf.keras.layers.Layer):
    def __init__(self, model_url, **kwargs):
        super(KerasLayerWrapper, self).__init__(**kwargs)
        self.model = hub.KerasLayer(model_url, trainable=False)
        
    def call(self, inputs):
        return self.model(inputs)


m = tf.keras.Sequential([
    KerasLayerWrapper("https://kaggle.com/models/google/resnet-v2/TensorFlow2/50-feature-vector/1"),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

m.build([None, 224, 224, 3])
# Out:
# WARNING:tensorflow:From C:\Users\kaust\anaconda3\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From C:\Users\kaust\anaconda3\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From C:\Users\kaust\anaconda3\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# WARNING:tensorflow:From C:\Users\kaust\anaconda3\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# WARNING:tensorflow:From C:\Users\kaust\anaconda3\Lib\site-packages\tf_keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# WARNING:tensorflow:From C:\Users\kaust\anaconda3\Lib\site-packages\tf_keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# WARNING:tensorflow:From C:\Users\kaust\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\core.py:192: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# WARNING:tensorflow:From C:\Users\kaust\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\core.py:192: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
m.compile(loss='categorical_crossentropy',
                     optimizer=tf.keras.optimizers.Adam(),
                     metrics=['accuracy'])

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',    
    patience=3,            
    restore_best_weights=True  
)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

Resnet_v2_50_history = m.fit(
    train_data_10_percent,
    epochs=20,
    validation_data=test_data,
    callbacks=[
        create_tensorboard_callback(dir_name="tensorflow_hub", experiment_name="Resnet_v2_50"),
        EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2)
    ]
)

if 'val_loss' in Resnet_v2_50_history.history:
    print("Validation Loss:", Resnet_v2_50_history.history['val_loss'])
else:
    print("Validation Loss key not found in history.")

if 'val_accuracy' in Resnet_v2_50_history.history:
    print("Validation Accuracy:", Resnet_v2_50_history.history['val_accuracy'])
else:
    print("Validation Accuracy key not found in history.")
# Out:
# Saving TensorBoard log files to: tensorflow_hub/Resnet_v2_50/20240814-185904
# Epoch 1/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.1992 - loss: 2.4064 - val_accuracy: 0.6100 - val_loss: 1.2403 - learning_rate: 0.0010
# Epoch 2/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - accuracy: 0.7303 - loss: 0.9693 - val_accuracy: 0.7152 - val_loss: 0.8686 - learning_rate: 0.0010
# Epoch 3/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 76s 3s/step - accuracy: 0.8231 - loss: 0.6363 - val_accuracy: 0.7464 - val_loss: 0.7812 - learning_rate: 0.0010
# Epoch 4/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - accuracy: 0.8915 - loss: 0.4791 - val_accuracy: 0.7616 - val_loss: 0.7124 - learning_rate: 0.0010
# Epoch 5/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 74s 3s/step - accuracy: 0.9163 - loss: 0.3631 - val_accuracy: 0.7728 - val_loss: 0.6979 - learning_rate: 0.0010
# Epoch 6/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 74s 3s/step - accuracy: 0.9256 - loss: 0.3184 - val_accuracy: 0.7748 - val_loss: 0.6734 - learning_rate: 0.0010
# Epoch 7/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 73s 3s/step - accuracy: 0.9662 - loss: 0.2501 - val_accuracy: 0.7748 - val_loss: 0.6543 - learning_rate: 0.0010
# Epoch 8/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 74s 3s/step - accuracy: 0.9690 - loss: 0.2157 - val_accuracy: 0.7828 - val_loss: 0.6428 - learning_rate: 0.0010
# Epoch 9/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 74s 3s/step - accuracy: 0.9827 - loss: 0.1878 - val_accuracy: 0.7832 - val_loss: 0.6338 - learning_rate: 0.0010
# Epoch 10/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 74s 3s/step - accuracy: 0.9940 - loss: 0.1498 - val_accuracy: 0.7900 - val_loss: 0.6296 - learning_rate: 0.0010
# Epoch 11/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 73s 3s/step - accuracy: 0.9939 - loss: 0.1288 - val_accuracy: 0.7888 - val_loss: 0.6320 - learning_rate: 0.0010
# Epoch 12/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 73s 3s/step - accuracy: 0.9925 - loss: 0.1241 - val_accuracy: 0.7896 - val_loss: 0.6237 - learning_rate: 0.0010
# Epoch 13/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 74s 3s/step - accuracy: 0.9945 - loss: 0.1055 - val_accuracy: 0.7852 - val_loss: 0.6293 - learning_rate: 0.0010
# Epoch 14/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - accuracy: 0.9963 - loss: 0.0982 - val_accuracy: 0.7936 - val_loss: 0.6204 - learning_rate: 0.0010
# Epoch 15/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.9978 - loss: 0.0859 - val_accuracy: 0.7888 - val_loss: 0.6291 - learning_rate: 0.0010
# Epoch 16/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - accuracy: 0.9965 - loss: 0.0787 - val_accuracy: 0.7896 - val_loss: 0.6254 - learning_rate: 0.0010
# Epoch 17/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 76s 3s/step - accuracy: 0.9998 - loss: 0.0684 - val_accuracy: 0.7916 - val_loss: 0.6222 - learning_rate: 2.0000e-04
# Validation Loss: [1.2402616739273071, 0.8685816526412964, 0.781222403049469, 0.7124077081680298, 0.6979328393936157, 0.673423707485199, 0.6543026566505432, 0.6428006887435913, 0.6338454484939575, 0.6295651793479919, 0.6319789886474609, 0.6237218976020813, 0.6292542815208435, 0.6204138398170471, 0.6290972232818604, 0.6253587603569031, 0.6221957206726074]
# Validation Accuracy: [0.6100000143051147, 0.7152000069618225, 0.746399998664856, 0.7616000175476074, 0.7728000283241272, 0.7748000025749207, 0.7748000025749207, 0.782800018787384, 0.7832000255584717, 0.7900000214576721, 0.7888000011444092, 0.7896000146865845, 0.7851999998092651, 0.7936000227928162, 0.7888000011444092, 0.7896000146865845, 0.7915999889373779]

# %%
val_loss, val_acc = m.evaluate(test_data, steps=len(test_data))
print(f"Validation Loss: {val_loss}, Validation Accuracy: {val_acc}")
# Out:
# C:\Users\kaust\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 57s 708ms/step - accuracy: 0.0818 - loss: 3.0108
# Validation Loss: 3.0105082988739014, Validation Accuracy: 0.0851999968290329

# %%
def plot_loss_curves(history):
    loss = history.history['loss']
    val_loss = history.history.get('val_loss', None)
    accuracy = history.history['accuracy']
    val_accuracy = history.history.get('val_accuracy', None)
    epochs = range(len(loss))

    plt.figure(figsize=(10, 6))
    plt.plot(epochs, loss, label='Training Loss')
    if val_loss:
        plt.plot(epochs, val_loss, label='Validation Loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

    plt.figure(figsize=(10, 6))
    plt.plot(epochs, accuracy, label='Training Accuracy')
    if val_accuracy:
        plt.plot(epochs, val_accuracy, label='Validation Accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
plot_loss_curves(Resnet_v2_50_history)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random

def view_random_image(target_dir, target_class):
  # Setup target directory (we'll view images from here)
  target_folder = target_dir+target_class

  # Get a random image path
  random_image = random.sample(os.listdir(target_folder), 1)

  # Read in the image and plot it using matplotlib
  img = mpimg.imread(target_folder + "/" + random_image[0])
  plt.imshow(img)
  plt.title(target_class)
  plt.axis("off");

  print(f"Image shape: {img.shape}") # show the shape of the image

  return img

# %%
plt.figure(figsize=(15, 6))

plt.subplot(2, 5, 1)
view_random_image("10_food_classes_10_percent/train/", "chicken_curry")
plt.title("Chicken Curry")

plt.subplot(2, 5, 2)
view_random_image("10_food_classes_10_percent/train/", "chicken_wings")
plt.title("Chicken Wings")

plt.subplot(2, 5, 3)
view_random_image("10_food_classes_10_percent/train/", "fried_rice")
plt.title("Fried Rice")

plt.subplot(2, 5, 4)
view_random_image("10_food_classes_10_percent/train/", "grilled_salmon")
plt.title("Grilled Salmon")

plt.subplot(2, 5, 5)
view_random_image("10_food_classes_10_percent/train/", "hamburger")
plt.title("Hamburger")

plt.subplot(2, 5, 6)
view_random_image("10_food_classes_10_percent/train/", "ice_cream")
plt.title("Ice Cream")

plt.subplot(2, 5, 7)
view_random_image("10_food_classes_10_percent/train/", "pizza")
plt.title("Pizza")

plt.subplot(2, 5, 8)
view_random_image("10_food_classes_10_percent/train/", "ramen")
plt.title("Ramen")

plt.subplot(2, 5, 9)
view_random_image("10_food_classes_10_percent/train/", "steak")
plt.title("Steak")

plt.subplot(2, 5, 10)
view_random_image("10_food_classes_10_percent/train/", "sushi")
plt.title("Sushi")

plt.tight_layout()
plt.show()
# Out:
# Image shape: (512, 512, 3)
# Image shape: (382, 512, 3)
# Image shape: (512, 512, 3)
# Image shape: (512, 512, 3)
# Image shape: (512, 512, 3)
# Image shape: (512, 512, 3)
# Image shape: (384, 512, 3)
# Image shape: (512, 512, 3)
# Image shape: (384, 512, 3)
# Image shape: (512, 384, 3)
